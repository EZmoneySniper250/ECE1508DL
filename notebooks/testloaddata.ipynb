# %%
from torch.utils.data import DataLoader
import sys
sys.path.append('..')
from dataset import SyntheticHomographyDataset
HPATCHES_PATH = "../hpatches-sequences-release"

# %%
raw_data = SyntheticHomographyDataset(image_dir=HPATCHES_PATH, num_pairs=1000, patch_size=256)
img0, img1, H_gt = DataLoader(raw_data, batch_size=4, shuffle=True).dataset[0]
print("img0 shape:", img0.shape)
print("img1 shape:", img1.shape)
print("H_gt shape:", H_gt.shape)
# Out:
# img0 shape: torch.Size([1, 256, 256])
# img1 shape: torch.Size([1, 256, 256])
# H_gt shape: torch.Size([3, 3])
